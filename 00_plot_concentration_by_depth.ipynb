# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import string

# ---------- Publication style (GCA: 190mm max width) ----------
DPI = 300
TARGET_WIDTH_MM = 190
TARGET_WIDTH_IN = TARGET_WIDTH_MM / 25.4  # 7.48 in

CORE_MAP = {
    "20892": "Station 27",
    "19908": "Station 15",
    "19119": "Station 5",
}

# Panel definitions: (elements, x-axis label)
PANELS = [
    (["Fe", "Ti", "Ca", "Si"], "Concentration (wt%)"),
    (["C", "N", "S"],          "Concentration (wt%)"),
]

# Distinct colors per element (shared across all panels)
ELEMENT_COLORS = {
    "Fe": "#d62728", "Ti": "#9467bd", "Ca": "#2ca02c",
    "Si": "#8c564b",
    "C":  "#1f77b4", "N":  "#ff7f0e",
    "S":  "#2ca02c",
}
ELEMENT_MARKERS = {
    "Fe": "o", "Ti": "D", "Ca": "s", "Si": "p",
    "C": "o", "N": "s",
    "S": "D",
}

# %%
# ---------- Load all XRF and CHNS data ----------
base = Path("elemental_composition")
frames = []

# XRF files
for f in sorted(base.glob("xrf/*_xrf.csv")):
    core_id = f.stem.split("_")[0]
    station = CORE_MAP.get(core_id, f"Core {core_id}")
    xrf = pd.read_csv(f)
    xrf.columns = xrf.columns.str.strip()

    # Normalise column names across formats
    col_map = {}
    for c in xrf.columns:
        cl = c.lower()
        if cl in ("depth", "depth_cm"):
            col_map[c] = "depth_cm"
        elif cl in ("component", "element"):
            col_map[c] = "element"
    xrf.rename(columns=col_map, inplace=True)

    # Handle string depths like "5 cm" vs int depths
    xrf["depth_cm"] = pd.to_numeric(xrf["depth_cm"], errors="coerce")
    if xrf["depth_cm"].isna().any():
        raw = pd.read_csv(f, usecols=[0])
        raw.columns = ["raw_depth"]
        xrf["depth_cm"] = raw["raw_depth"].astype(str).str.extract(r"(\d+)").astype(int)
    xrf["depth_cm"] = xrf["depth_cm"].astype(int)

    xrf["element"] = xrf["element"].astype(str).str.strip()

    xrf_long = xrf[["depth_cm", "element", "Result", "Unit"]].copy()
    xrf_long.columns = ["depth_cm", "element", "value", "unit"]
    xrf_long["core_id"] = core_id
    xrf_long["station"] = station
    xrf_long["source"] = "XRF"
    frames.append(xrf_long)

# CHNS files
for f in sorted(base.glob("chns/*_chns.csv")):
    core_id = f.stem.split("_")[0]
    station = CORE_MAP.get(core_id, f"Core {core_id}")
    chns = pd.read_csv(f)
    chns.columns = chns.columns.str.strip()
    chns["depth_cm"] = chns["sample name"].str.extract(r"(\d+)cm").astype(int)

    # Melt element columns (C%, N%, etc.)
    elem_cols = [c for c in chns.columns if c.endswith("%")]
    melted = chns.melt(
        id_vars=["depth_cm"], value_vars=elem_cols,
        var_name="element", value_name="value",
    )
    melted["element"] = melted["element"].str.replace("%", "")
    melted["unit"] = "wt%"
    melted["source"] = "CHNS"
    melted["core_id"] = core_id
    melted["station"] = station
    frames.append(melted)

    # C/N ratio
    ratio = chns.melt(
        id_vars=["depth_cm"], value_vars=["C/N ratio"],
        var_name="element", value_name="value",
    )
    ratio["element"] = "C/N"
    ratio["unit"] = "molar"
    ratio["source"] = "CHNS"
    ratio["core_id"] = core_id
    ratio["station"] = station
    frames.append(ratio)

df = pd.concat(frames, ignore_index=True)
cores = sorted(df["core_id"].unique(), key=lambda x: CORE_MAP.get(x, x))
print(f"Cores loaded: {cores}")
print(f"Elements available: {sorted(df['element'].unique())}")
# Out:
# Cores loaded: ['19908', '20892', '19119']
# Elements available: ['Ag', 'Al', 'Ba', 'Br', 'C', 'C/N', 'Ca', 'Cl', 'Cu', 'Fe', 'H', 'K', 'Mg', 'Mn', 'N', 'Na', 'P', 'Rb', 'Rh', 'Ru', 'S', 'Si', 'Sr', 'Ti', 'V', 'Zn', 'Zr']

# %%
# ---------- Figure: 2-row × N-station grid ----------
n_rows = len(PANELS)
n_cols = len(cores)
panel_labels = list(string.ascii_lowercase)
panel_idx = 0

# GCA double-column: 190mm wide, height scaled to ~55% of width
fig_h = TARGET_WIDTH_IN * 0.55
fig, axes = plt.subplots(
    n_rows, n_cols,
    figsize=(TARGET_WIDTH_IN, fig_h),
    dpi=DPI, squeeze=False,
)

# Y-axis settings common to all panels
ymax = df["depth_cm"].max()
yticks = [1, 3, 5, 7, 9, 11, 13, 15]

# Station title(s) across the top
for col_idx, core_id in enumerate(cores):
    station = CORE_MAP.get(core_id, f"Core {core_id}")
    axes[0, col_idx].set_title(station, fontsize=7, fontweight="bold")

for col_idx, core_id in enumerate(cores):
    core_df = df[df["core_id"] == core_id]

    for row_idx, (elements, xlabel) in enumerate(PANELS):
        ax = axes[row_idx, col_idx]

        xmax = 0
        for elem in elements:
            subset = core_df[core_df["element"] == elem]
            if subset.empty:
                continue

            stats = (subset.groupby("depth_cm")["value"]
                     .agg(["mean", "std"]).reset_index()
                     .sort_values("depth_cm"))

            upper = (stats["mean"] + stats["std"].fillna(0)).max()
            if upper > xmax:
                xmax = upper

            ax.errorbar(
                stats["mean"], stats["depth_cm"],
                xerr=stats["std"], fmt="none",
                color=ELEMENT_COLORS.get(elem, "#333"),
                capsize=1.5, elinewidth=0.4,
            )
            ax.plot(
                stats["mean"], stats["depth_cm"],
                linestyle=":", color=ELEMENT_COLORS.get(elem, "#333"),
                linewidth=0.5,
            )
            ax.scatter(
                stats["mean"], stats["depth_cm"],
                marker=ELEMENT_MARKERS.get(elem, "o"),
                color=ELEMENT_COLORS.get(elem, "#333"),
                s=8, zorder=3, label=elem,
                edgecolors="white", linewidths=0.2,
            )

        ax.set_xlim(0, xmax * 1.45 if xmax > 0 else 1)
        ax.set_ylim(ymax + 1, -0.5)
        ax.set_yticks(yticks)
        ax.set_ylabel("Depth (cm)", fontsize=6)
        ax.set_xlabel(xlabel, fontsize=6)

        ax.tick_params(labelsize=5, direction="in", length=2, width=0.4, pad=1.5)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        for spine in ("bottom", "left"):
            ax.spines[spine].set_linewidth(0.4)

        ax.text(-0.18, 1.02, f"({panel_labels[panel_idx]})",
                transform=ax.transAxes, fontsize=6, fontweight="bold",
                va="bottom", ha="left")
        panel_idx += 1

        if len(elements) > 1:
            ax.legend(fontsize=4.5, loc="lower right", frameon=False,
                      handlelength=1.0, labelspacing=0.2, handletextpad=0.4)

fig.subplots_adjust(hspace=0.45, wspace=0.45)

# Save
for ext in ("png", "pdf"):
    outpath = Path("dewey-etal_gp17-sediments/figures") / f"figure_elemental_depth_profiles.{ext}"
    fig.savefig(outpath, dpi=DPI, bbox_inches="tight",
                facecolor="white", pad_inches=0.05)
    print(f"Saved: {outpath}")

plt.show()
# Out:
# Saved: dewey-etal_gp17-sediments/figures/figure_elemental_depth_profiles.png
# Saved: dewey-etal_gp17-sediments/figures/figure_elemental_depth_profiles.pdf
